# %%
import os
import json
from pathlib import Path
import pandas as pd

import get_file_info
from pathlib import Path
import shutil
import xarray as xr


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = get_file_info.run()
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = get_file_info.run()
#       2 df
#
# NameError: name 'get_file_info' is not defined

# %%
df_lost = df.loc[df['file_path'].isnull()]
df_lost

# %%
tar_dir = r'F:\cy\Database\CMIP6\0_origin\all'
for index, row in df.iterrows():
    old_path = row['file_path']
    if not old_path.startswith(tar_dir):
        print(old_path)
# Out:
# F:\cy\Database\CMIP6\0_origin\hurs\AWI-CM-1-1-MR\ssp245\hurs_day_AWI-CM-1-1-MR_ssp126_r1i1p1f1_gn_20150101-20151231.ncTrue
# F:\cy\Database\CMIP6\0_origin\hurs\AWI-CM-1-1-MR\ssp245\hurs_day_AWI-CM-1-1-MR_ssp126_r1i1p1f1_gn_20180101-20181231.ncTrue
# F:\cy\Database\CMIP6\0_origin\hurs\AWI-CM-1-1-MR\ssp245\hurs_day_AWI-CM-1-1-MR_ssp126_r1i1p1f1_gn_20190101-20191231.ncTrue
# F:\cy\Database\CMIP6\0_origin\hurs\AWI-CM-1-1-MR\ssp245\hurs_day_AWI-CM-1-1-MR_ssp126_r1i1p1f1_gn_20220101-20221231.ncTrue
# F:\cy\Database\CMIP6\0_origin\hurs\AWI-CM-1-1-MR\ssp245\hurs_day_AWI-CM-1-1-MR_ssp126_r1i1p1f1_gn_20250101-20251231.ncTrue
# F:\cy\Database\CMIP6\0_origin\hurs\AWI-CM-1-1-MR\ssp245\hurs_day_AWI-CM-1-1-MR_ssp126_r1i1p1f1_gn_20290101-20291231.ncTrue
# F:\cy\Database\CMIP6\0_origin\hurs\AWI-CM-1-1-MR\ssp245\hurs_day_AWI-CM-1-1-MR_ssp126_r1i1p1f1_gn_20320101-20321231.ncTrue
# F:\cy\Database\CMIP6\0_origin\hurs\AWI-CM-1-1-MR\ssp245\hurs_day_AWI-CM-1-1-MR_ssp126_r1i1p1f1_gn_20440101-20441231.ncTrue
# ...

# %%
df1 = df.drop_duplicates(subset='file_path', keep='first')
df1
# Out:
#                                                file_path
# 0      F:\cy\Database\CMIP6\0_origin\hurs\AWI-CM-1-1-...  \
# 1      F:\cy\Database\CMIP6\0_origin\hurs\AWI-CM-1-1-...
# 2      F:\cy\Database\CMIP6\0_origin\hurs\AWI-CM-1-1-...
# 3      F:\cy\Database\CMIP6\0_origin\hurs\AWI-CM-1-1-...
# 4      F:\cy\Database\CMIP6\0_origin\hurs\AWI-CM-1-1-...
# ...                                                  ...
# 16731  F:\cy\Database\CMIP6\0_origin\vas\MPI-ESM1-2-H...
# 16732  F:\cy\Database\CMIP6\0_origin\vas\MPI-ESM1-2-H...
# 16733  F:\cy\Database\CMIP6\0_origin\vas\MPI-ESM1-2-H...
# 16734  F:\cy\Database\CMIP6\0_origin\vas\MPI-ESM1-2-H...
# 16735  F:\cy\Database\CMIP6\0_origin\vas\MPI-ESM1-2-H...
#
#                                                 filename
# 0      hurs_day_AWI-CM-1-1-MR_ssp126_r1i1p1f1_gn_2015...
# 1      hurs_day_AWI-CM-1-1-MR_ssp126_r1i1p1f1_gn_2016...
# 2      hurs_day_AWI-CM-1-1-MR_ssp126_r1i1p1f1_gn_2017...
# ...

# %%
import wget

wget.download(url='')
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 1826, bnds: 2, lat: 192, lon: 384)
# Coordinates:
#   * time       (time) datetime64[ns] 2070-01-01T12:00:00 ... 2074-12-31T12:00:00
#   * lat        (lat) float64 -89.28 -88.36 -87.42 -86.49 ... 87.42 88.36 89.28
#   * lon        (lon) float64 0.0 0.9375 1.875 2.812 ... 356.2 357.2 358.1 359.1
#     height     float64 ...
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] ...
#     lat_bnds   (lat, bnds) float64 ...
#     lon_bnds   (lon, bnds) float64 ...
#     hurs       (time, lat, lon) float32 ...
# Attributes: (12/47)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            ScenarioMIP
#     branch_method:          standard
#     branch_time_in_child:   60265.0
#     branch_time_in_parent:  60265.0
#     contact:                cmip6-mpi-esm@dkrz.de
#     ...                     ...
#     title:                  MPI-ESM1-2-HR output prepared for CMIP6
# ...

# %%
df = ds.to_dataframe()
df
# Out:
#                                               time_bnds  lat_bnds   lon_bnds
# time                bnds lat        lon
# 2070-01-01 12:00:00 0    -89.284228 0.0000   2070-01-01 -89.74784   -0.46875  \
#                                     0.9375   2070-01-01 -89.74784    0.46875
#                                     1.8750   2070-01-01 -89.74784    1.40625
#                                     2.8125   2070-01-01 -89.74784    2.34375
#                                     3.7500   2070-01-01 -89.74784    3.28125
# ...                                                 ...       ...        ...
# 2074-12-31 12:00:00 1     89.284228 355.3125 2075-01-01  89.74784  355.78125
#                                     356.2500 2075-01-01  89.74784  356.71875
#                                     357.1875 2075-01-01  89.74784  357.65625
#                                     358.1250 2075-01-01  89.74784  358.59375
#                                     359.0625 2075-01-01  89.74784  359.53125
#
# ...

# %%
for index, row in df_except.iterrows():
    file_path = row['file_path']
    filename = row['filename']
    if not filename.endswith('.nc'):
        os.remove(file_path)
        print(file_path)
# Out:
# F:\cy\Database\CMIP6\0_origin\hurs\AWI-CM-1-1-MR\ssp126\hurs_day_AWI-CM-1-1-MR_ssp126_r1i1p1f1_gn_20830101-20831231.nchu7_r5_j.tmp
# F:\cy\Database\CMIP6\0_origin\hurs\AWI-CM-1-1-MR\ssp126\hurs_day_AWI-CM-1-1-MR_ssp126_r1i1p1f1_gn_20920101-20921231.nc1417k33k.tmp
# F:\cy\Database\CMIP6\0_origin\hurs\AWI-CM-1-1-MR\ssp126\hurs_day_AWI-CM-1-1-MR_ssp245_r1i1p1f1_gn_20600101-20601231.nc9ne7jt7c.tmp
# F:\cy\Database\CMIP6\0_origin\hurs\AWI-CM-1-1-MR\ssp245\hurs_day_AWI-CM-1-1-MR_ssp126_r1i1p1f1_gn_20480101-20481231.nclmi1nl4d.tmp
# F:\cy\Database\CMIP6\0_origin\hurs\AWI-CM-1-1-MR\ssp245\hurs_day_AWI-CM-1-1-MR_ssp245_r1i1p1f1_gn_20180101-20181231.ncv0krqj7i.tmp
# F:\cy\Database\CMIP6\0_origin\hurs\AWI-CM-1-1-MR\ssp245\hurs_day_AWI-CM-1-1-MR_ssp245_r1i1p1f1_gn_20210101-20211231.ncr_n3fvwp.tmp
# F:\cy\Database\CMIP6\0_origin\hurs\AWI-CM-1-1-MR\ssp245\hurs_day_AWI-CM-1-1-MR_ssp245_r1i1p1f1_gn_20350101-20351231.nc_g871so9.tmp
# ...
